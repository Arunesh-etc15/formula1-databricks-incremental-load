-- %% [markdown]
-- #Set upenvironment for formula1 project
-- 1.create external location databricksstoragea
--
-- 2.create catalog formula1

-- %%
show catalogs;

-- %%
CREATE SCHEMA if not EXISTS formula1_catalog.control 
  MANAGED LOCATION 'abfss://formula1@databricksstoragea.dfs.core.windows.net/control' ;

-- %%
select current_catalog();

-- %%
use catalog formula1_catalog;

-- %%
show schemas

-- %%
create table if not exists formula1_catalog.control.batch_events(
    batch_id int,
    event_timestamp timestamp
)

-- %%
insert into formula1_catalog.control.batch_events values(2, current_timestamp())

-- %%
select * from formula1_catalog.control.batch_events
